# %%
# 台形の面積の計算結果を出力するプログラム
# 公式：台形の面積 =（上辺＋下辺）× 高さ ÷ 2
number1 = 10
number2 = 20
number3 = 5
print(f"{(number1 + number2) * number3 / 2}cm²")
# Out:
# 75.0cm²

# %%
# 台形の面積の計算結果を出力するプログラム
# 公式：台形の面積 =（上辺＋下辺）× 高さ ÷ 2
number1 = 10
number2 = 20
number3 = 5

# 変数を用いて出力するように修正
area = (number1 + number2) * number3 / 2

print(f"{area}cm²")
# Out:
# 75.0cm²

# %% [markdown]
# # 新しいセクション
